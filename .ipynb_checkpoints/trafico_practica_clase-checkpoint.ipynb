# %%
import pandas as pd

# %%
trafico = pd.read_csv("Average_Daily_Traffic_Counts.csv")

# %%
trafico.head()
# Out:
#     ID  Traffic Volume Count Location  Address    Street Date of Count  \
# 0   414                              5838 West   Lake St    11/14/2006
# 1   176                               320 East   76th St    03/28/2006
# 2   715                              835 North  Clark St    09/20/2006
# 3   316                               125 East   24th St    03/30/2006
# 4  1294                              2924 East  130th St    08/29/2006
#
#    Total Passing Vehicle Volume Vehicle Volume By Each Direction of Traffic  \
# 0                          7100         East Bound: 3600 / West Bound: 3500
# 1                          8600         East Bound: 3800 / West Bound: 4800
# 2                         16500     South Bound: 16500/ Oneway South Bound
# 3                           700           East Bound: 400 / West Bound: 300
# 4                          4200         East Bound: 2300 / West Bound: 1900
#
#     Latitude  Longitude                 Location  Boundaries - ZIP Codes  \
# ...

# %%
trafico.shape
# Out:
# (1279, 15)

# %%
trafico.dtypes
# Out:
# ID                                               int64
# Traffic Volume Count Location  Address          object
# Street                                          object
# Date of Count                                   object
# Total Passing Vehicle Volume                     int64
# Vehicle Volume By Each Direction of Traffic     object
# Latitude                                       float64
# Longitude                                      float64
# Location                                        object
# Boundaries - ZIP Codes                         float64
# Community Areas                                float64
# Zip Codes                                        int64
# Census Tracts                                  float64
# Wards                                          float64
# :@computed_region_awaf_s7ux                    float64
# dtype: object

# %%
trafico.shape
# Out:
# (1279, 15)

# %%
trafico.describe()
# Out:
#                ID   Total Passing Vehicle Volume     Latitude    Longitude  \
# count  1279.000000                   1279.000000  1279.000000  1279.000000
# mean    689.937451                  19466.301798    41.849394   -87.670298
# std     395.568121                  12448.378467     0.083917     0.060891
# min       1.000000                    700.000000    41.651861   -87.854842
# 25%     348.500000                  11350.000000    41.780249   -87.710013
# 50%     684.000000                  17300.000000    41.871380   -87.662850
# 75%    1028.500000                  24200.000000    41.909196   -87.628631
# max    1382.000000                 165200.000000    42.017888   -87.529702
#
#        Boundaries - ZIP Codes  Community Areas     Zip Codes  Census Tracts  \
# count             1266.000000      1266.000000   1279.000000    1265.000000
# mean                32.849921        37.849921  18520.457389     369.827668
# ...

# %%
trafico.count()
# Out:
# ID                                             1279
# Traffic Volume Count Location  Address         1279
# Street                                         1279
# Date of Count                                  1279
# Total Passing Vehicle Volume                   1279
# Vehicle Volume By Each Direction of Traffic    1279
# Latitude                                       1279
# Longitude                                      1279
# Location                                       1279
# Boundaries - ZIP Codes                         1266
# Community Areas                                1266
# Zip Codes                                      1279
# Census Tracts                                  1265
# Wards                                          1266
# :@computed_region_awaf_s7ux                    1266
# dtype: int64

# %%
trafico[trafico.duplicated()].shape
# Out:
# (0, 15)

# %%
trafico.tail()
# Out:
#        ID  Traffic Volume Count Location  Address        Street Date of Count  \
# 1274  1154                              806 North      State St    09/21/2006
# 1275   396                            13200 South  Torrence Ave    11/08/2006
# 1276   762                             3121 South    Pulaski Rd    09/14/2006
# 1277   257                               256 East       35th St    03/29/2006
# 1278   950                             2032 North    Pulaski Rd    10/05/2006
#
#       Total Passing Vehicle Volume  \
# 1274                         21100
# 1275                         15100
# 1276                         29500
# 1277                         10200
# 1278                         21300
#
#      Vehicle Volume By Each Direction of Traffic   Latitude  Longitude  \
# 1274      North Bound: 9900 / South Bound: 11200  41.896924 -87.628206
# 1275       North Bound: 7400 / South Bound: 7700  41.655545 -87.559298
# ...

# %%
trafico.ID.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-3d0826f6f217> in <module>
# ----> 1 trafico.ID.value_counts()
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'ID'

# %%
trafico([ID])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-1959bd6469cd> in <module>
# ----> 1 trafico([ID])
#
# NameError: name 'ID' is not defined
